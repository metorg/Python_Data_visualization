# %%
# konlpy 라이브러리 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.4MB/s
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/50/49/725710351d78d26c65337b1e3b322d7b27b34b704535ab56afc0d9ab0ffd/JPype1-1.0.1-cp36-cp36m-manylinux2010_x86_64.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 21.3MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/bb/7c/99d51f80f3b77b107ebae2634108717362c059a41384a1810d13e2429a81/tweepy-3.9.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 7.8MB/s
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.2)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.6/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Installing collected packages: JPype1, tweepy, colorama, beautifulsoup4, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.0.1 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.9.0

# %% [markdown]
# # 새 섹션

# %%
# Matplotlib 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# %config InlineBackend.figure_format = 'retina'

# !apt-get -qq -y install fonts-nanum > /dev/null

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
# 파이썬프로그래밍활용 1급 실기과제-2 #

from bs4 import BeautifulSoup
import requests
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd


# 키워드 검색 뉴스 가사 타이틀 가져오기 
def get_news_titles(start_num, end_num):  
    
    while True :
        if start_num > end_num:
            break
 
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}&start={}'.format(search_word, start_num)
    
        response = requests.get(url) 
        html = response.text
        soup = BeautifulSoup(html, "html.parser")
                   
        # 뉴스 타이틀 가져오기
        titles = soup.select('ul.type01 > li > dl > dt > a')
        
        # 뉴스 타이틀을 list에 저장
        for title in titles:
            title_list.append(title['title'])
            
        start_num += 10  # 읽어올 기사 수 조정 

    # 수집한 기사 타이틀 출력
    for no, title in enumerate(title_list, start=1) :
      print(no, title) 
    print("-"* 120)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f437aac19ecb> in <module>()
#      18
#      19 # 단어 빈도수 세기
# ---> 20 count = Counter(noun_adj_list)
#
# NameError: name 'noun_adj_list' is not defined

# %%
# 워드 클라우드 그리기
def make_wordcloud(wordcount):
    
    okt = Okt() 
    sentences_tag = []
    
    # 형태소로 분석하여 리스트에 넣기
    for sentence in title_list:
        morph = okt.pos(sentence)
        sentences_tag.append(morph)
 
    noun_adj_list = []
    # 형태소 중 명사와 형용사만 리스트에 넣기
    for sentence in sentences_tag:
        for word, tag in sentence:
            if tag in ['Noun', 'Adjective']:
                noun_adj_list.append(word)
    
    # 단어 빈도수 세기
    count = Counter(noun_adj_list)
      
    # 빈도수가 높은 단어 50개 추출, 글자 길이가 2이상인 단어만 추출
    wordInfo = dict()
    for tags, counts in count.most_common(wordcount):
        if len(wordInfo) >= 50 :   # 빈도수가 높은 단어 50개 추출
            break
        if (len(str(tags)) > 1):  # 글자 길이가 2이상인 단어만 추출
            wordInfo[tags] = counts
            print ("%s : %d" % (tags, counts))
      
    # wordcloud 객체 생성(한글깨지는 문제 해결하기위해 font_path 지정)
    font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
    wc = WordCloud(font_path = font_path,
                              background_color='white', width=600, height=480)
    # wordcloud 객체에 데이터 매핑
    wc.generate_from_frequencies(wordInfo)

    # wordcloud 그리기
    plt.figure(figsize=(10, 6))
    plt.axis('off')
    plt.imshow(wc)
    plt.show()
        
    # 워드 클라우드 그림 파일로 저장하기    
    wc.to_file('2007-00359-이승민-3.png')   # 수험번호와 이름을 입력해주세요.

# %%
# 메인 프로그램     
if __name__ == '__main__':
    
    search_word ='신종코로나' # 키워드 검색
    title_list = []

# 뉴스 기사 타이틀 크롤링(시작 ~ 끝)
get_news_titles(1, 50)
 
# 워드클라우드 그리기
make_wordcloud(100)
# Out:
# 1 올해 예비군훈련, 코로나에 하루 4시간으로 축소…52년만에 처음(종합)
# 2 GC녹십자, 코로나19 혈장치료제 임상 2상 신청
# 3 GC녹십자, 코로나19 혈장치료제 임상2상 신청
# 4 GC녹십자엠에스, '코로나 진단키트 수출 덕' 2분기 영업익 전년比 10배 증가
# 5 "땡큐, 신사업!" GS건설 코로나19에도 매출 성장세
# 6 코로나19 이후 5개월…대기업 직원 1만명 이상 줄었다
# 7 수퍼컴퓨터로 '코로나19 치료제' 설계했다
# 8 올해 예비군 훈련, 코로나에 하루 4시간으로 축소…9월부터 실시
# 9 올해 예비군 훈련, 코로나로 하루 4시간만…9월부터 재개
# 10 신종플루 무료접종 했는데 '코로나 백신' 가격은?
# 11 WHO "북한서 최근 1천200여명 코로나 검사, 약 700명 격리"
# 12 GC녹십자엠에스, '코로나 진단키트 수출 덕' 2분기 영업익 전년比 10배 증가
# 13 WHO "北 코로나 1,200여명 검사…확진자는 제로"
# 14 코로나 시대 소비 키워드 'DISTANCE'…'거리두기'
# 15 코로나 5개월…대기업 직원 1만2천명 줄었다
# 16 화웨이 수석부사장 "코로나19 대처하려면 공동으로 노력해야"
# 17 ‘코로나19’ 확진자 48명 추가…해외유입 34명, 지역발생 14명
# 18 코로나19 이후 5개월…대기업 직원 1만명 이상 줄었다
# 19 <10문10답>전세계 ‘코로나 백신 개발’ 현황·전망
# 20 수퍼컴퓨터로 '코로나19 치료제' 설계했다
# 21 WHO "코로나19 계절 타지 않는다"
# 22 미국만 39달러? 코로나 백신 화이자 모더나 가격은(종합)
# 23 검찰, '코로나 방역 방해' 신천지 이만희 구속영장 청구(종합)
# 24 SKT, 코로나19 방역 돕는 '누구 케어콜' 지원 확대
# 25 "손님 줄었다고 연차 쓰래요"…코로나19 확산 속 '휴가 갑질'
# 26 삼성SDI, 코로나 19에도 ‘기대 이상 성적’
# 27 코로나19가 생물학무기? 러시아, 미국대선 앞 괴담 유포 정황
# 28 "코로나19는 정신병" 벨라루스 대통령 황당 주장
# 29 코로나19 가짜뉴스 올렸다고…트럼프 장남 트위터 계정 일시제한
# 30 "코로나19 해외유입 우려에" … 외국인 유학생, 2학기에도 원격수강 권고
# 31 "모더나, 코로나19 백신 코스 당 50~60달러 제안" FT
# 32 빌 게이츠 "코로나 치료제 연내 개발, 사망률 낮아질 것"
# 33 ‘코로나 때문에’...세계 최대 IT전시회 CES 2021, 온라인으로 열린다
# 34 WHO, 한여름 다돼서야... "코로나 바이러스 계절 타지 않아"
# 35 [속보] 미 연구팀 "코로나19 감염 막는 면역단백질 발견"
# 36 집값은 올라도…코로나에 오피스·상가 수익률↓ 공실률↑
# 37 SK텔레콤, 광주 서구에 코로나19 모니터링 서비스 제공
# 38 코로나가 계기됐나···EU도 對中제재
# 39 코로나19 우려에 CES 2021도 '온라인'으로
# 40 [속보] 日코로나 신규 확진 1천명 '첫' 돌파…누적 3만4천명
# 41 코로나 12월 진정설…파우치-백신·빌게이츠-치료제 언급
# 42 코로나19로 중단된 태권도대회 재개…30일 중·고등대회 개막
# 43 대기업도 못 피한 코로나19… 5개월 새 직원 1만명 이상 감소
# 44 [속보] 코로나19 신규 확진 48명...지역사회 14명·해외유입 34명
# 45 중기 절반 이상 "코로나로 외국인근로자 입국 막혀 생산 차질"
# 46 화이자, 모더나, 아스트라제네카…코로나19 백신 가격은 얼마?
# 47 JB금융지주, 코로나19 등 경영환경 악화속에서 선방
# 48 코로나19 위기의식 일상에 스미는 북한…도시 곳곳에 '방역초소'
# 49 코로나로 해외 막혔지만....삼성엔지니어링 2분기에도 흑자
# 50 정부, 여행업계 코로나 피해 실태 점검…제주여행상품 할인
# ------------------------------------------------------------------------------------------------------------------------
# 코로나 : 50
# 치료 : 6
# 백신 : 6
# 이상 : 5
# 녹십자 : 4
# 개월 : 4
# 대기업 : 4
# 직원 : 4
# 해외 : 4
# 올해 : 3
# 예비군 : 3
# 훈련 : 3
# 하루 : 3
# 종합 : 3
# 가격 : 3
# 유입 : 3
# 방역 : 3
# 속보 : 3
# 축소 : 2
# 혈장 : 2
# 신청 : 2
# 엠에스 : 2
# 진단 : 2
# 키트 : 2
# 수출 : 2
# 영업 : 2
# 증가 : 2
# 이후 : 2
# 수퍼컴퓨터 : 2
# 설계 : 2
# 재개 : 2
# 북한 : 2
# 여명 : 2
# 검사 : 2
# 진자 : 2
# 지역 : 2
# 개발 : 2
# 계절 : 2
# 타지 : 2
# 미국 : 2
# 화이자 : 2
# 삼성 : 2
# 우려 : 2
# 외국인 : 2
# 온라인 : 2
# 신규 : 2
# 확진 : 2
# 대회 : 2
# 여행 : 2
# 처음 : 1

# %% [markdown]
# # 새 섹션
